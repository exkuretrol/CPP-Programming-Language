// %% [markdown]
// # 程式設計（一）作業

// %% [markdown]
// - **截止日期：**10/14
// - **目標：**練習使用運算子

// %% [markdown]
// <div style="display: flex; flex-direction: row-reverse; width: 100%">
// <p style="text-align: left; margin-left: auto">
//     姓名：陳家瑋<br>
//     學號：08170875
// </p>
// </div>

// %%
!echo "start at: $(date +%F\ %T)"
// Out:
// start at: 2022-10-14 15:05:10

// %% [markdown]
// <div class="alert alert-block alert-info">
//     2-1. 輸入一整數 n，計算立方，並輸出其結果。
// </div>

// %% [markdown]
// ![CleanShot 2022-10-14 at 15.03.35@2x.png](attachment:68647520-c747-42c0-b004-7a6498342e62.png)

// %%
// 08170875-陳家瑋-HW1
// include libraries
#include <iostream>
#include <iomanip>
// bring everything in the namespace into scope
using namespace std;

// %%
cout << "hw2-1 請輸入1個正整數: ";

int a;
cin >> a;
cout << "立方: " << a * a * a;
// Out:
// hw2-1 請輸入1個正整數:
//  44
// 立方: 85184

// %% [markdown]
// <div class="alert alert-block alert-info">
//     2-2. 輸入半徑 r，計算圓面積 pi*r*r(p=3.14)，並輸出結果。
// </div>

// %% [markdown]
// ![CleanShot 2022-10-14 at 15.04.06@2x.png](attachment:acba49a0-077f-4dd0-abf7-7e138b936008.png)

// %%
cout << "hw2-2 請輸入半徑: ";

float r;
float pi = 3.14;
cin >> r;

cout << "圓面積: " << r * r * pi << endl;
// Out:
// hw2-2 請輸入半徑:
//  12.1
// 圓面積: 459.727

// %%
!echo "finished at: $(date +%F\ %T)"
// Out:
// finished at: 2022-10-14 15:06:30
