// %% [markdown]
// # 程式設計（一）作業

// %% [markdown]
// - **截止日期：**10/14
// - **目標：**練習使用運算子

// %% [markdown]
// <div style="display: flex; flex-direction: row-reverse; width: 100%">
// <p style="text-align: left; margin-left: auto">
//     姓名：陳家瑋<br>
//     學號：08170875
// </p>
// </div>

// %%
!echo "start at: $(date +%F\ %T)"
// Out:
// start at: 2022-10-14 14:10:01

// %% [markdown]
// <div class="alert alert-block alert-info">
//     1-1. 輸入兩個正整數 a、b，輸出 a 與 b 的各算術運算子其結果。
// </div>

// %% [markdown]
// ![CleanShot 2022-10-14 at 14.11.01@2x.png](attachment:eb0e0bd3-e9d7-426f-a43e-6144d2250c25.png)

// %%
// 08170875-陳家瑋-HW1
// include libraries
#include <iostream>
#include <iomanip>
// bring everything in the namespace into scope
using namespace std;

// %%
cout << "hw1-1 請輸入2個正整數: ";

int a, b;
cin >> a >> b;

cout << "a + b = " << a + b << endl;
cout << "a - b = " << a - b << endl;
cout << "a * b = " << a * b << endl;
cout << "a / b = " << a / b << endl;
cout << "a % b = " << a % b << endl;
// Out:
// hw1-1 請輸入2個正整數:
//  2 4
// a + b = 6
// a - b = -2
// a * b = 8
// a / b = 0
// a % b = 2

// %% [markdown]
// <div class="alert alert-block alert-info">
//     1-2. 輸入一整數 n，計算平方，並輸出其結果。
// </div>

// %% [markdown]
// ![CleanShot 2022-10-14 at 14.18.17@2x.png](attachment:d20b923b-5702-40c6-9234-4775bf3cdda7.png)

// %%
cout << "hw1-2 請輸入1個整數: ";

int c;
cin >> c;

cout << "平方: " << c * c << endl;
// Out:
// hw1-2 請輸入1個整數:
//  43
// 平方: 1849

// %%
!echo "finished at: $(date +%F\ %T)"
// Out:
// finished at: 2022-10-14 14:16:29
