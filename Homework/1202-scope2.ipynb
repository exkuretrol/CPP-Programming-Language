// %% [markdown]
// # 程式設計（一）作業

// %% [markdown]
// - **截止日期：**09/21
// - **目標：**輸入輸出

// %% [markdown]
// <div style="display: flex; flex-direction: row-reverse; width: 100%">
// <p style="text-align: left; margin-left: auto">
//     姓名：陳家瑋<br>
//     學號：08170875
// </p>
// </div>

// %% [markdown]
// <div class="alert alert-block alert-info">
//     題號 2: 試利用 auto 宣告一個浮點數變數 f，請由鍵盤輸入其值，印出
// 大於 f 的最小整數。
// </div>

// %% [markdown]
// ![CleanShot 2022-12-02 at 15.11.28@2x.png](attachment:6307a450-03d4-4288-a26f-a925d131fd8a.png)

// %%
!echo "start at: $(date +%F\ %T)"
// Out:
// start at: 2022-12-02 15:07:09

// %%
#include <iostream>
using namespace std;

// %%
auto float f = 0;
cout << "請輸入一個浮點數:";
cin >> f;
cout << "大於" << f << "的最小整數是" << (int) ceil(f);
// Out:
// input_line_9:2:2: warning: 'auto' storage class specifier is not permitted in C++11, and will not be supported in future releases [-Wauto-storage-class]
//  auto float f = 0;
//  ^~~~~
// 請輸入一個浮點數:
//  5.6
// 大於5.6的最小整數是6

// %%
!echo "finished at: $(date +%F\ %T)"
// Out:
// finished at: 2022-12-02 15:10:46
