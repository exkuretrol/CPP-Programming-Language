// %% [markdown]
// # 程式設計（一）作業

// %% [markdown]
// - **截止日期：**09/23
// - **目標：**跳脫字元

// %% [markdown]
// <div style="display: flex; flex-direction: row-reverse; width: 100%">
// <p style="text-align: left; margin-left: auto">
//     姓名：陳家瑋<br>
//     學號：08170875
// </p>
// </div>

// %% [markdown]
// <div class="alert alert-block alert-info">
//     請同學使用3個跳脫字元，來完成此作業，並截圖(包含程式碼+執行結果)上傳。
// 第1行需註解學號-姓名。
// </div>

// %%
!echo "start at: $(date +%F\ %T)"
// Out:
// start at: 2022-09-30 21:18:01

// %%
// 08170875-陳家瑋
// include libraries
#include<iostream>
// bring everything in the namespace into scope
using namespace std;

// %% [markdown]
// ![image.png](attachment:1ae4e561-bf9d-46e4-bd68-bcd861fab867.png)

// %% [markdown]
// source: https://www.geeksforgeeks.org/escape-sequences-c/

// %%
cout << "alarm or beep: " << "\a" << endl;
cout << "backspace: " << "\b" << endl;
cout << "form feed: " << "\f" << endl;
cout << "new line: " << "\n" << endl;
cout << "carriage return: " << "\r" << endl;
cout << "tab (horizontal): " << "\t" << "." << endl;
cout << "vertical tab: " << "\v" << endl;
cout << "backslash: " << "\\" << endl;
cout << "single quote: " << "\'" << endl;
cout << "double quote: " << "\"" << endl;
cout << "question mark: " << "\?" << endl;
cout << "octal number: " << "\000" << endl;
cout << "hexadecimal number: " << "\x0A" << endl;
cout << "null: " << "\0" << endl;
// Out:
// alarm or beep:
// backspace:
// form feed:
// new line:
//
// carriage return:
// tab (horizontal): 	.
// vertical tab:
// backslash: \
// single quote: '
// double quote: "
// question mark: ?
// octal number:
// hexadecimal number:
//
// null:

// %%
!echo "finished at: $(date +%F\ %T)"
// Out:
// finished at: 2022-09-30 21:31:26
