// %% [markdown]
// # 程式設計（一）作業

// %% [markdown]
// - **截止日期：**09/30
// - **目標：**格式化輸出

// %% [markdown]
// <div style="display: flex; flex-direction: row-reverse; width: 100%">
// <p style="text-align: left; margin-left: auto">
//     姓名：陳家瑋<br>
//     學號：08170875
// </p>
// </div>

// %% [markdown]
// > 用以下3個格式，將變數123的8、10、16進位顯示出來。<br>
// >    8進位格式要為`cout<< ... <<var`<br>
// >    10進位格式要為`cout.setf(...)`<br>
// >    16進位格式要為`setbase(...)`<br>
// > 1行需註解學號-姓名-HW3。<br>
// > 名:學號-姓名-HW3。。

// %% [markdown]
// ![image.png](attachment:142a5cad-1e43-4629-866d-a232215e430f.png)

// %%
!echo "start at: $(date +%F\ %T)"
// Out:
// start at: 2022-09-30 22:24:05

// %%
// 08170875-陳家瑋-HW3
// include libraries
#include <iostream>
#include <iomanip>
// bring everything in the namespace into scope
using namespace std;

// %%
?std::basic_iostream
// Out:
// https://en.cppreference.com/w/cpp/io/basic_iostream

// %%
int i = 123;
cout << "123 in oct is " << oct << i << endl;
// Out:
// 123 in oct is 173

// %%
cout.setf(std::ios::dec, std::ios::basefield);
cout << "123 in dec is " << i << endl;
// Out:
// 123 in dec is 123

// %%
cout << "123 in hex is " << setbase(16) << i << endl;
// Out:
// 123 in hex is 7b

// %%
!echo "finished at: $(date +%F\ %T)"
// Out:
// finished at: 2022-09-30 22:36:45
