// %% [markdown]
// # 程式設計（一）作業

// %% [markdown]
// - **截止日期：**10/28
// - **目標：**流程控制

// %% [markdown]
// <div style="display: flex; flex-direction: row-reverse; width: 100%">
// <p style="text-align: left; margin-left: auto">
//     姓名：陳家瑋<br>
//     學號：08170875
// </p>
// </div>

// %%
!echo "start at: $(date +%F\ %T)"
// Out:
// start at: 2022-10-28 15:02:37

// %%
#include <iostream>
using namespace std;

// %% [markdown]
// <div class="alert alert-block alert-info">
//     作業 2-1：
// 印出從 1 到 100 之間，可同時被 7 整除，又可以被 4 整除的數
// 值。
// </div>

// %% [markdown]
// ![CleanShot 2022-10-28 at 15.02.52@2x.png](attachment:7b69530f-f0e2-4705-acde-c3303de86013.png)

// %%
cout << "1~100中可同時被7與4整除的數有 ";
for (int i = 1; i <= 100; i++)
    if (i % 7 == 0 && i % 4 == 0)
        cout << i << " ";
// Out:
// 1~100中可同時被7與4整除的數有 28 56 84

// %%
!echo "finished at: $(date +%F\ %T)"
// Out:
// finished at: 2022-10-28 14:16:35
