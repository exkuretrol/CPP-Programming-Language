// %% [markdown]
// # 程式設計（一）作業

// %% [markdown]
// - **截止日期：**1007
// - **目標：**ASCII Code

// %% [markdown]
// <div style="display: flex; flex-direction: row-reverse; width: 100%">
// <p style="text-align: left; margin-left: auto">
//     姓名：陳家瑋<br>
//     學號：08170875
// </p>
// </div>

// %% [markdown]
// > 使用ASCII碼印出 "Coding"及"csie"的結果。<br>
// > 第1行需註解學號-姓名-HW6。<br>
// > 檔名:學號-姓名-HW6。

// %% [markdown]
// ![image.png](attachment:e6f7d2f7-2fd7-440b-9ab8-690c5a373550.png)

// %%
!echo "start at: $(date +%F\ %T)"
// Out:
// start at: 2022-10-14 15:17:20

// %% [markdown]
// ![image.png](attachment:f6fef9e4-4e7a-456d-9826-e34e762cbb27.png)

// %%
// 08170875-陳家瑋-HW6
// include libraries
#include <iostream>
#include <iomanip>
// bring everything in the namespace into scope
using namespace std;

// %%
cout << char(67) << char(111) << char(100) << char(105) << char(110) << char(103) << endl;
//      C           o            d            i            n            g

cout << (int) 'c' << (int) 's' << (int) 'i' << (int) 'e' << endl;
// Out:
// Coding
// 99115105101

// %%
!echo "finished at: $(date +%F\ %T)"
// Out:
// finished at: 2022-10-14 15:22:49
