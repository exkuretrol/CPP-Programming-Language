// %% [markdown]
// # 程式設計（一）作業

// %% [markdown]
// - **截止日期：**10/21
// - **目標：**流程處理

// %% [markdown]
// <div style="display: flex; flex-direction: row-reverse; width: 100%">
// <p style="text-align: left; margin-left: auto">
//     姓名：陳家瑋<br>
//     學號：08170875
// </p>
// </div>

// %% [markdown]
// <div class="alert alert-block alert-info">
//     HW 1-1: 試撰寫一程式，由鍵盤輸入一個整數值，然後判斷它是奇數或
// 偶數。
// </div>

// %% [markdown]
// ![CleanShot 2022-10-21 at 14.26.18@2x.png](attachment:d91c1284-4972-43bd-8f4e-92b0868365bc.png)

// %%
!echo "start at: $(date +%F\ %T)"
// Out:
// start at: 2022-10-21 14:25:44

// %%
#include <iostream>
using namespace std;

// %%
// 08170875-陳家瑋-HW1-1
void Is_Odd()
{
    int x;

    cin >> x;
    string odd_or_not = (x % 2 == 1) ? "奇數" : "偶數";

    cout << x << "是" << odd_or_not;
}
Is_Odd();
// Out:
//  0
// 0是偶數

// %%
Is_Odd();
// Out:
//  1
// 1是奇數

// %%
!echo "finished at: $(date +%F\ %T)"
// Out:
// finished at: 2022-10-21 14:43:19
