// %% [markdown]
// # 程式設計（一）作業

// %% [markdown]
// - **截止日期：**10/28
// - **目標：**流程控制

// %% [markdown]
// <div style="display: flex; flex-direction: row-reverse; width: 100%">
// <p style="text-align: left; margin-left: auto">
//     姓名：陳家瑋<br>
//     學號：08170875
// </p>
// </div>

// %%
!echo "start at: $(date +%F\ %T)"
// Out:
// start at: 2022-10-28 14:07:14

// %%
#include <iostream>
using namespace std;

// %% [markdown]
// <div class="alert alert-block alert-info">
//     題號 1-2：試利用 for 迴圈與 if 敘述，撰寫一程式，印出從 1 到 100 之
// 間，所有可以被 18 整除的數值。
// </div>

// %% [markdown]
// ![CleanShot 2022-10-28 at 14.15.04@2x.png](attachment:6f031f57-d21e-4ab3-b41f-64cace66bb17.png)

// %%
cout << "1~100中可被18整除的數有 ";
for (int i = 1; i <= 100; i++)
{
    if (i % 18 == 0) cout << i << " ";
}
// Out:
// 1~100中可被18整除的數有 18 36 54 72 90

// %%
!echo "finished at: $(date +%F\ %T)"
// Out:
// finished at: 2022-10-28 14:16:35
