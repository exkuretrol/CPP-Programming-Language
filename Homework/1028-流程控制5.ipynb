// %% [markdown]
// # 程式設計（一）作業

// %% [markdown]
// - **截止日期：**10/28
// - **目標：**流程控制

// %% [markdown]
// <div style="display: flex; flex-direction: row-reverse; width: 100%">
// <p style="text-align: left; margin-left: auto">
//     姓名：陳家瑋<br>
//     學號：08170875
// </p>
// </div>

// %%
!echo "start at: $(date +%F\ %T)"
// Out:
// start at: 2022-10-28 16:04:57

// %%
#include <iostream>
using namespace std;

// %% [markdown]
// <div class="alert alert-block alert-info">
//     作業 3：輸入一整數 n，用"*"畫出一個 n 層的三角形。
// </div>

// %% [markdown]
// ![CleanShot 2022-10-28 at 16.04.41@2x.png](attachment:9051f2d6-0b62-4246-b58b-05d6d099623c.png)

// %%
cout << "輸入一整數：";
int k;
cin >> k;
for (int k = 1; k <= 5; k++)
    cout << string(k, '*') << endl;
// Out:
// 輸入一整數：
//  5
// *
// **
// ***
// ****
// *****

// %%
!echo "finished at: $(date +%F\ %T)"
// Out:
// finished at: 2022-10-28 16:13:25
