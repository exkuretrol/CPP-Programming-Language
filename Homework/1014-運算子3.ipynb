// %% [markdown]
// # 程式設計（一）作業

// %% [markdown]
// - **截止日期：**10/14
// - **目標：**練習使用運算子

// %% [markdown]
// <div style="display: flex; flex-direction: row-reverse; width: 100%">
// <p style="text-align: left; margin-left: auto">
//     姓名：陳家瑋<br>
//     學號：08170875
// </p>
// </div>

// %%
!echo "start at: $(date +%F\ %T)"
// Out:
// start at: 2022-10-14 16:09:12

// %% [markdown]
// <div class="alert alert-block alert-info">
//     3-1. 輸入半徑 r，計算球體積 4/3*pi*r^3 (pi=3.14)，並輸出結果。
// </div>

// %% [markdown]
// ![CleanShot 2022-10-14 at 16.01.55@2x.png](attachment:6da6af47-4f58-4f1a-89a1-e8c2a272357e.png)

// %%
// 08170875-陳家瑋-HW3
// include libraries
#include <iostream>
#include <iomanip>
// bring everything in the namespace into scope
using namespace std;

// %%
cout << "hw3-1 請輸入半徑: ";

float r;
float pi = 3.14;
cin >> r;
cout << "球體積: " << 4 / 3 * pi * r * r * r << endl;
// Out:
// hw3-1 請輸入半徑:
//  5.2
// 球體積: 441.509

// %% [markdown]
// <div class="alert alert-block alert-info">
//     3-2. 輸入矩形的長與寬，輸出其周長。周長=2×(長+寬)。
// </div>

// %% [markdown]
// ![CleanShot 2022-10-14 at 16.02.09@2x.png](attachment:669da859-86bd-45b7-a429-1465bcc13d7a.png)

// %%
cout << "hw3-2 請輸入矩形的長與寬: ";

float l, w;
cin >> l >> w;

cout << "周長: " << (l + w) * 2 << endl;
// Out:
// hw3-2 請輸入矩形的長與寬:
//  2.1 6.5
// 周長: 17.2

// %%
!echo "finished at: $(date +%F\ %T)"
// Out:
// finished at: 2022-10-14 16:09:17
