// %% [markdown]
// # 程式設計（一）作業

// %% [markdown]
// - **截止日期：**09/30
// - **目標：**格式化輸出

// %% [markdown]
// <div style="display: flex; flex-direction: row-reverse; width: 100%">
// <p style="text-align: left; margin-left: auto">
//     姓名：陳家瑋<br>
//     學號：08170875
// </p>
// </div>

// %% [markdown]
// > 如下圖程式碼，請同學利用setw()、setfill()將程式碼做修改，並截圖(包含程式碼+執行結果)上傳。<br>
// > 第1行需註解學號-姓名-HW2。<br>
// > 檔名:學號-姓名-HW2。

// %% [markdown]
// ![image.png](attachment:65db9506-af73-42d9-ae38-e91c34d57324.png)

// %%
!echo "start at: $(date +%F\ %T)"
// Out:
// start at: 2022-09-30 22:10:00

// %%
// 08170875-陳家瑋-HW2
// include libraries
#include <iostream>
#include <cstdlib>
// bring everything in the namespace into scope
using namespace std;

// %%
?cout
// Out:
// https://en.cppreference.com/w/cpp/io/basic_ostream

// %%
int i = 123;
cout << "i = ";
cout.width(5);
cout.fill('@');
cout << i << endl;
// Out:
// i = @@123

// %%
// include libraries
#include <iostream>
#include <cstdlib>
#include <iomanip>

// %%
int i = 123;
cout << "i = " << setw(5) << setfill('@') << i << endl;
// Out:
// i = @@123

// %%
!echo "finished at: $(date +%F\ %T)"
// Out:
// finished at: 2022-09-30 22:21:12
